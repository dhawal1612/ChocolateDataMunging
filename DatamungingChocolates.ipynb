# %% [markdown]
# # Chocolate Database - Data Munging Notebook
# ### Sources: USDA Food Composition Website, CSV files, Twitter

# %%
# Importing relevant libraries
import os
from bs4 import BeautifulSoup
import urllib3
import pandas as pd
import re
from itertools import repeat
import csv
import numpy as np
import time
from tweepy import API
from tweepy import Cursor
from tweepy import TweepError
from tweepy import OAuthHandler


# importing Twitter API keys from file
import t_credentials as twitter_credentials

# %% [markdown]
# ## Part I - Scraping USDA Food Composition Database Website

# %%
"""
Input parameters for the 3 part run.
    data_folder - mentions the folder location where data to and from is accessed
    csvfile - name of the merged csv file containing all the parsed data
    url_used - URL of the webite scraped
    brands_regex - RegEx to search relevant chocolate brands
    
@Author: Dhawal Priyadarshi
@Created On: Jan 2019
"""

#*********** User Input Parameters  ***********
# Path to data folder
# data_folder = os.getcwd() + "\\data\\"     # for Windows
data_folder = os.getcwd() + '/data/'         # for Mac and Linux
# File for data storage
csvfile="chocolates_master_file.csv"
# URL of the USDA website (chocolate lookup)
url_used ="https://ndb.nal.usda.gov/ndb/search/list?fgcd=&manu=&lfacet=&count=&max=25&sort=default&\
qlookup=chocolate&offset=0&format=Full&new=&measureby=&ds=&order=asc&qt=&qp=&qa=&qn=&q=&ing="
# Brands search RegEx
brands_regex = r"ghirardelli*|lindt*|mondelez*|mars*|hersheys*|taza*"
#**********************************************

print("Parameters are set!")
# Out:
# Parameters are set!

# %%
"""
Extracts data-rows from USDA website on even and odd positions for each page out of the 511 pages and appends 
the data to a list, which is then written into the csv file row by row

@Author: Mansi Nagraj
@Created On: Jan 2019
"""

# Setting run variables
filepath = data_folder + csvfile
offset=0
myWebData = []
http = urllib3.PoolManager()
urllib3.disable_warnings()     # disable SSL warnings

try:
    print("Writing file to", filepath)
    with open(filepath, "a") as output:
        writer = csv.writer(output, dialect='excel')
        # Writing header for the csv file:    
        writer.writerow(["Db","Ndb Id","FoodDescription","Manufacturer"])
        for i in range(1,511):
            new_url= url_used.replace(url_used[113:114] ,str(offset))
            offset=offset+25
            req = http.request('GET', new_url)
            soup = BeautifulSoup(req.data, 'html.parser')
            even_titles = soup.find_all('tr', {"class":"even"})
            odd_titles = soup.find_all('tr', {"class":"odd"})
            # Collecting data for even-numbered rows:        
            for even_title in even_titles:
                cols= even_title.find_all('td')
                myWebData = []
                for col in cols:
                    row_data =col.get_text()
                    evenRowdData= row_data.strip()
                    myWebData.append(evenRowdData)
                writer.writerow(myWebData)
            # Collecting data for odd-numbered rows:             
            for odd_title in odd_titles:
                cols= odd_title.find_all('td')
                myWebData = []
                for col in cols:
                    row_data =col.get_text()
                    oddRowData= row_data.strip()
                    myWebData.append(oddRowData)
                writer.writerow(myWebData)
        print("Scraping completed!")
except BaseException as e:
    print("Base Exception: %s" % str(e))
# Out:
# Writing file to /Users/dhawal/proj/Scraping/data/chocolates_master_file.csv
# Scraping completed!

# %%
# Displaying the scraped dataset
sitedf = pd.read_csv(filepath)
sitedf
# Out:
#        Db    Ndb Id                                    FoodDescription  \
# 0      BF  45157421  CHOCOLATE CHOCOLATE CHOCOLATE, DARK CHOCOLATE ...
# 1      BF  45148721  CHOCOLATE CHOCOLATE CHOCOLATE, WHITE CHOCOLATE...
# 2      BF  45286717  MILK CHOCOLATE, DARK CHOCOLATE, CARAMEL & MILK...
# 3      BF  45148724  CHOCOLATE CHOCOLATE CHOCOLATE, ALMOND TOFFEE B...
# 4      BF  45136309  CHOCOLATE COOKIES WITH CHOCOLATE CHIPS, UPC: 6...
# 5      BF  45149559  GHIRARDELLI CHOCOLATE, CHOCOLATE SQUARES, UPC:...
# 6      BF  45007105  CHOCOLATE CORTES, SWEET CHOCOLATE, UPC: 073693...
# 7      BF  45013346  SHOPRITE, CHOCOLATE SYRUP, CHOCOLATE, UPC: 041...
# 8      BF  45151749  ELMER CHOCOLATE, ASSORTED CHOCOLATES, UPC: 041...
# 9      BF  45143245  ELMER CHOCOLATE, ASSORTED CHOCOLATES, UPC: 041...
# 10     BF  45155648      ELMER CHOCOLATE, CHOCOLATE, UPC: 041761100400
# 11     BF  45100142  DILETTANTE CHOCOLATES, DARK CHOCOLATES, UPC: 0...
# 12     BF  45157408  CHOCOLATE CHOCOLATE CHOCOLATE, MILK CHOCOLATE ...
# 13     BF  45148722  CHOCOLATE CHOCOLATE CHOCOLATE, DARK CHOCOLATE ...
# 14     BF  45364413  MILK CHOCOLATE, DARK CHOCOLATE, MILK CHOCOLATE...
# 15     BF  45165180  CHOCOLATE CHOCOLATE CHOCOLATE, CARROT CAKE, CA...
# 16     BF  45277935  CHOCOLATE CREME & CHOCOLATE COOKIES, UPC: 0723...
# 17     BF  45143244  ELMER CHOCOLATE, ASSORTED CHOCOLATES, UPC: 041...
# 18     BF  45143243  ELMER CHOCOLATE, ASSORTED CHOCOLATES, UPC: 041...
# 19     BF  45150158  WHITE CHOCOLATE WITH CHOCOLATE CANDIES, UPC: 8...
# 20     BF  45154454  TEJAS CHOCOLATE, DARK CHOCOLATE, UPC: 85903700...
# 21     BF  45147021      ELMER CHOCOLATE, CHOCOLATE, UPC: 041761100530
# 22     BF  45157064  ELMER CHOCOLATE, ASSORTED CHOCOLATE, UPC: 0417...
# 23     BF  45117943  CHOCOLATE CORTES, GROUND CHOCOLATE, UPC: 07369...
# 24     BF  45098875  VALOR CHOCOLATES, DARK CHOCOLATE, UPC: 0722474...
# 25     BF  45164387  VSC CHOCOLATES, CHOCOLATE TRUFFLES, UPC: 05541...
# 26     BF  45164072  ELMER CHOCOLATE, ASSORTED CHOCOLATES, UPC: 041...
# 27     BF  45162496  MADELAINE CHOCOLATE COMPANY, CHOCOLATE, UPC: 0...
# 28     BF  45206369   TAZA CHOCOLATE, CHOCOLATE BAR, UPC: 898456001081
# 29     SR     19081                           Candies, sweet chocolate
# ...    ..       ...                                                ...
# 12720  BF  45092067  KLONDIKE, BARS, ARTIFICIALLY FLAVORED VANILLA ...
# 12721  BF  45284723  VANILLA ICE CREAM WITH PEANUT BUTTER FILLED MI...
# 12722  BF  45166367  THE CHEESECAKE XPRESS, CHEESECAKE SIPPI, CHEES...
# 24                      Delta Brands Intl Corp
# 25                                        none
# 26                     ELMER CANDY CORPORATION
# 27               Madelaine Chocolate Novelties
# 28                              TAZA CHOCOLATE
# 29                                      Sweets
# ...                                        ...
# 12720               The Isaly Klondike Company
# 12721                        Big Y Foods, Inc.
# 12722               Southern Sweet Treat's LLC
# 12723                 United Dairy Farmers Inc
# 12724                   Topco Associates, Inc.
# 12725             Whidbey Island Ice Cream LLC
# 12726        Hammond's Candies Since 1920, LLC
# 12727                                      QTG
# 12728                                      QTG
# 12729                   Dairy and Egg Products
# 12730                   Dairy and Egg Products
# 12731                                Beverages
# 12732                                Beverages
# 12733                                Beverages
# 12734                           Baked Products
# 12735                           Baked Products
# 12736                                   Sweets
# 12737  DOUBLE RAINBOW GOURMET ICE CREAMS, INC.
# 12738         Mondelez Int. US (0074819091009)
# 12739                                      QTG
# 12740                                      QTG
# 12741                                      QTG
# 12742                   Dairy and Egg Products
# 12743                        Breakfast Cereals
# 12744                                Beverages
# 12745                                Beverages
# 12746              Legumes and Legume Products
# 12747                           Baked Products
# 12748                                   Sweets
# 12749                                   Sweets
#
# [12750 rows x 4 columns]

# %%
"""
Subsetting the data using user-defined RegEx

@Author: Dhawal Priyadarshi, Mansi Nagraj
@Created On: Jan 2019
"""

all_match = list(map(re.search, repeat(brands_regex\
                                       , len(sitedf['Manufacturer'])), sitedf['Manufacturer'] \
                                       , repeat(re.IGNORECASE, len(sitedf['Manufacturer']))))

s = np.bitwise_not(pd.isnull(all_match))
sitedf_filtered = sitedf[s]
sitedf_filtered.head(15)
# Out:
#     Db    Ndb Id                                    FoodDescription  \
# 5   BF  45149559  GHIRARDELLI CHOCOLATE, CHOCOLATE SQUARES, UPC:...
# 14  BF  45364413  MILK CHOCOLATE, DARK CHOCOLATE, MILK CHOCOLATE...
# 28  BF  45206369   TAZA CHOCOLATE, CHOCOLATE BAR, UPC: 898456001081
# 31  BF  45318593     DARK CHOCOLATE CHOCOLATE CANDES, UPC: 04045805
# 33  BF  45161032  GHIRARDELLI CHOCOLATE, CHOCOLATE, ASSORTED, UP...
# 43  BF  45318613  CHOCOLATE CANDIES DARK CHOCOLATE, UPC: 0400004...
# 45  BF  45318362  CHOCOLATE CANDIES, DARK CHOCOLATE, UPC: 040000...
# 48  BF  45166054  GHIRARDELLI CHOCOLATE, MILK CHOCOLATE, UPC: 74...
# 54  BF  45149557  GHIRARDELLI CHOCOLATE, SPRING IMPRESSIONS CHOC...
# 58  BF  45153637  GHIRARDELLI CHOCOLATE, WINTER WHITE HOLIDAY SQ...
# 59  BF  45375481  TERRY'S CHOCOLATE ORANGE CHOCOLATE BAR-BUNDLE ...
# 60  BF  45375882  TERRY'S CHOCOLATE ORANGE CHOCOLATE PIECES ASSO...
# 64  BF  45086419  GHIRARDELLI CHOCOLATE, MILK CHOCOLATE, UPC: 74...
# 70  BF  45048920  GHIRARDELLI CHOCOLATE, HOLIDAY SEA SALT DUO SQ...
# 72  BF  45375749  TERRY'S CHOCOLATE ORANGE CHOCOLATE BAR-BUNDLE ...
#
#                         Manufacturer
# 5      GHIRARDELLI CHOCOLATE COMPANY
# 14  Mars Chocolate North America LLC
# 28                    TAZA CHOCOLATE
# 31  Mars Chocolate North America LLC
# 33     GHIRARDELLI CHOCOLATE COMPANY
# 43  Mars Chocolate North America LLC
# 45  Mars Chocolate North America LLC
# 48     GHIRARDELLI CHOCOLATE COMPANY
# 54     GHIRARDELLI CHOCOLATE COMPANY
# 58     GHIRARDELLI CHOCOLATE COMPANY
# 59                 Mondelez EU B2B2C
# 60                 Mondelez EU B2B2C
# 64     GHIRARDELLI CHOCOLATE COMPANY
# 70     GHIRARDELLI CHOCOLATE COMPANY
# 72                 Mondelez EU B2B2C

# %%
# Randomly selecting 20 rows from the filtered data-frame
# final_sample = sitedf_filtered.sample(20)

# Using fixed Ndb IDs for the purpose of demonstration (based on the downloaded csv files in "data" folder)
filterList = ['45318621','45145291','45318334','45053347','45148117','45376125','45375537','45318454','45369935'\
         ,'45375781','45375900','45158103','45153224','45236273','45375862','45331173','45143068','45004850'\
         ,'45158934','45208905']
final_sample = sitedf_filtered[sitedf_filtered['Ndb Id'].isin(filterList)]
final_sample
# Out:
#        Db    Ndb Id                                    FoodDescription  \
# 1012   BF  45318621               CHOCOLATE CANDIES, UPC: 040000249085
# 1095   BF  45318454               CHOCOLATE CANDIES, UPC: 040000483632
# 1576   BF  45236273  WEIS QUALITY, 1% LOW FAT CHOCOLATE MILK, CHOCO...
# 2305   BF  45331173         MILK CHOCOLATE TRUFFLES, UPC: 009542034610
# 3027   BF  45158103  SOUTHERN HOME, CHOCOLATE STARS, UPC: 607880038897
# 4061   BF  45158934  GHIRARDELLI CHOCOLATE, MINIS ASSORTMENT, UPC: ...
# 4502   BF  45148117  KINGS, GRAHAMS, DARK CHOCOLATE, UPC: 073866104779
# 5460   BF  45004850  WEIS, SANDWICH KREMES, CHOCOLATE, UPC: 0414975...
# 5643   BF  45053347      DARK CHOCOLATE NON PAREILS, UPC: 041497499458
# 5690   BF  45208905      PREMIUM MILK CHOCOLATE BAR, UPC: 086854060049
# 8232   BF  45145291  WILD HARVEST, CHOCOLATE CHIP COOKIES, UPC: 711...
# 8527   BF  45153224  MARKETSIDE, CRISPY CHOCOLATE CHIP TOFFEE COOKI...
# 8918   BF  45318334  MILK CHOCOLATE & STRAWBERRY CREME SWIRL, UPC: ...
# 9978   BF  45143068  CHOCOLATE RAISINS WITH SEA SALT CARAMEL, UPC: ...
# 10290  BF  45375537  CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT, UNP...
# 10323  BF  45375781  CADBURY FLAKE CHOCOLATE BAR, UNPREPARED, GTIN:...
# 10366  BF  45375900  CADBURY FREDDO CHOCOLATE BAR, UNPREPARED, GTIN...
# 11520  BF  45369935  NABISCO OREO CONES CHOCOLATE 1X4.750 OZ, UNPRE...
# 12435  BF  45375862  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR, ...
# 12475  BF  45376125  CADBURY CHOCOLATE BAR FUDGE 127.500 GR, UNPREP...
#
#                            Manufacturer
# 1012   Mars Chocolate North America LLC
# 1095   Mars Chocolate North America LLC
# 1576                 WEIS MARKETS, INC.
# 2305      Lindt & Sprungli (Schweiz) AG
# 3027         Bruno's Supermarkets, Inc.
# 4061      GHIRARDELLI CHOCOLATE COMPANY
# 4502            Kings Super Markets Inc
# 5460                 WEIS MARKETS, INC.
# 5643                 WEIS MARKETS, INC.
# 5690                Ingles Markets Inc.
# 8232                   Star Markets Co.
# 8527              WAL-MART STORES, INC.
# 8918   Mars Chocolate North America LLC
# 9978         PUBLIX SUPER MARKETS, INC.
# 10290                 Mondelez EU B2B2C
# 10323                 Mondelez EU B2B2C
# 10366                 Mondelez EU B2B2C
# 11520  Mondelez Int. US (0074819091009)
# 12435                 Mondelez EU B2B2C
# 12475                 Mondelez EU B2B2C

# %% [markdown]
# ## Part II - Reading data from CSV files

# %%
def NutrientFunction(fn):
    """
    Function to extract the Nutrient data from the different csv files and return parsed dataset
    
    @Author: Mansi Nagraj
    @Created On: Jan 2019
    """
    rows=[]
    inp=[]
    filename = data_folder + str(fn)+'.csv'
    with open(filename , newline='') as csvfile:
        inputfile = csv.reader(csvfile)
        for row in inputfile:
            inp.append(row)
        mylist=[8,11,16,17,19]
        nutrientlist = []
        for n in mylist:
            nut = inp[n][:6]
            nutrientlist.append(nut)
        nutrientdf=pd.DataFrame(nutrientlist,columns=["Nutrient","Unit","DataPoint","StdError","Weight","Value"])
    nutrientdf['Ndb Id']= fn
    return nutrientdf

# Gathering the parsed data from each CSV file into one dataframe
all_results = pd.DataFrame(columns=["Nutrient","Unit","Value","Ndb Id"])
for n in final_sample['Ndb Id']:
    results = NutrientFunction(n)
    all_results = all_results.append(results)
    
all_results.head(15)
# Out:
# /Users/dhawal/proj/Scraping/venv/lib/python3.7/site-packages/pandas/core/frame.py:6701: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#   DataPoint    Ndb Id                     Nutrient StdError  Unit  Value  \
# 0        --  45318621                       Energy       --  kcal    476
# 1        --  45318621  Carbohydrate, by difference       --     g  73.81
# 2        --  45318621                     Iron, Fe       --    mg   0.86
# 3        --  45318621                   Sodium, Na       --    mg     71
# 4        --  45318621                Vitamin A, IU       --    IU    238
# 0        --  45318454                       Energy       --  kcal    524
# 1        --  45318454  Carbohydrate, by difference       --     g  57.14
# 2        --  45318454                     Iron, Fe       --    mg   0.86
# 3        --  45318454                   Sodium, Na       --    mg    214
# 4        --  45318454                Vitamin A, IU       --    IU    238
# 0        --  45236273                       Energy       --  kcal     62
# 1        --  45236273  Carbohydrate, by difference       --     g  10.00
# 2        --  45236273                     Iron, Fe       --    mg   0.15
# 3        --  45236273                Phosphorus, P       --    mg     83
# 4      None  45236273                     Vitamins     None  None   None
#
#   Weight
# 0    200
# 1  31.00
# 2   0.36
# 3     30
# 4    100
# 0    220
# 1  24.00
# 2   0.36
# 3     90
# 4    100
# 0    149
# 1  24.00
# 2   0.36
# 3    199
# 4   None

# %%
# Merging scraped and file based data into one dataframe

# Branded Food DB
bfdb = pd.concat([final_sample.set_index('Ndb Id'),all_results.set_index('Ndb Id')], axis=1, join='inner')
bfdb
# Out:
#           Db                                    FoodDescription  \
# Ndb Id
# 45318621  BF               CHOCOLATE CANDIES, UPC: 040000249085
# 45318621  BF               CHOCOLATE CANDIES, UPC: 040000249085
# 45318621  BF               CHOCOLATE CANDIES, UPC: 040000249085
# 45318621  BF               CHOCOLATE CANDIES, UPC: 040000249085
# 45318621  BF               CHOCOLATE CANDIES, UPC: 040000249085
# 45318454  BF               CHOCOLATE CANDIES, UPC: 040000483632
# 45318454  BF               CHOCOLATE CANDIES, UPC: 040000483632
# 45318454  BF               CHOCOLATE CANDIES, UPC: 040000483632
# 45318454  BF               CHOCOLATE CANDIES, UPC: 040000483632
# 45318454  BF               CHOCOLATE CANDIES, UPC: 040000483632
# 45236273  BF  WEIS QUALITY, 1% LOW FAT CHOCOLATE MILK, CHOCO...
# 45236273  BF  WEIS QUALITY, 1% LOW FAT CHOCOLATE MILK, CHOCO...
# 45236273  BF  WEIS QUALITY, 1% LOW FAT CHOCOLATE MILK, CHOCO...
# 45236273  BF  WEIS QUALITY, 1% LOW FAT CHOCOLATE MILK, CHOCO...
# 45236273  BF  WEIS QUALITY, 1% LOW FAT CHOCOLATE MILK, CHOCO...
# 45331173  BF         MILK CHOCOLATE TRUFFLES, UPC: 009542034610
# 45331173  BF         MILK CHOCOLATE TRUFFLES, UPC: 009542034610
# 45331173  BF         MILK CHOCOLATE TRUFFLES, UPC: 009542034610
# 45331173  BF         MILK CHOCOLATE TRUFFLES, UPC: 009542034610
# 45331173  BF         MILK CHOCOLATE TRUFFLES, UPC: 009542034610
# 45158103  BF  SOUTHERN HOME, CHOCOLATE STARS, UPC: 607880038897
# 45158103  BF  SOUTHERN HOME, CHOCOLATE STARS, UPC: 607880038897
# 45158103  BF  SOUTHERN HOME, CHOCOLATE STARS, UPC: 607880038897
# 45158103  BF  SOUTHERN HOME, CHOCOLATE STARS, UPC: 607880038897
# 45158103  BF  SOUTHERN HOME, CHOCOLATE STARS, UPC: 607880038897
# 45158934  BF  GHIRARDELLI CHOCOLATE, MINIS ASSORTMENT, UPC: ...
# 45158934  BF  GHIRARDELLI CHOCOLATE, MINIS ASSORTMENT, UPC: ...
# 45158934  BF  GHIRARDELLI CHOCOLATE, MINIS ASSORTMENT, UPC: ...
# 45158934  BF  GHIRARDELLI CHOCOLATE, MINIS ASSORTMENT, UPC: ...
# 45158934  BF  GHIRARDELLI CHOCOLATE, MINIS ASSORTMENT, UPC: ...
# ...       ..                                                ...
# 45375537  BF  CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT, UNP...
# 45375537  BF  CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT, UNP...
# 45375537  BF  CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT, UNP...
# 45375537  BF  CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT, UNP...
# 45375537  BF  CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT, UNP...
# 45375781  BF  CADBURY FLAKE CHOCOLATE BAR, UNPREPARED, GTIN:...
# 45375781  BF  CADBURY FLAKE CHOCOLATE BAR, UNPREPARED, GTIN:...
# 45375781  BF  CADBURY FLAKE CHOCOLATE BAR, UNPREPARED, GTIN:...
# 45375781  BF  CADBURY FLAKE CHOCOLATE BAR, UNPREPARED, GTIN:...
# 45375781  BF  CADBURY FLAKE CHOCOLATE BAR, UNPREPARED, GTIN:...
# 45375900  BF  CADBURY FREDDO CHOCOLATE BAR, UNPREPARED, GTIN...
# 45375900  BF  CADBURY FREDDO CHOCOLATE BAR, UNPREPARED, GTIN...
# 45375900  BF  CADBURY FREDDO CHOCOLATE BAR, UNPREPARED, GTIN...
# 45375900  BF  CADBURY FREDDO CHOCOLATE BAR, UNPREPARED, GTIN...
# 45375900  BF  CADBURY FREDDO CHOCOLATE BAR, UNPREPARED, GTIN...
# 45369935  BF  NABISCO OREO CONES CHOCOLATE 1X4.750 OZ, UNPRE...
# 45369935  BF  NABISCO OREO CONES CHOCOLATE 1X4.750 OZ, UNPRE...
# 45369935  BF  NABISCO OREO CONES CHOCOLATE 1X4.750 OZ, UNPRE...
# 45369935  BF  NABISCO OREO CONES CHOCOLATE 1X4.750 OZ, UNPRE...
# 45369935  BF  NABISCO OREO CONES CHOCOLATE 1X4.750 OZ, UNPRE...
# 45375862  BF  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR, ...
# 45375862  BF  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR, ...
# 45375862  BF  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR, ...
# 45375862  BF  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR, ...
# 45375862  BF  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR, ...
# 45376125  BF  CADBURY CHOCOLATE BAR FUDGE 127.500 GR, UNPREP...
# 45376125  BF  CADBURY CHOCOLATE BAR FUDGE 127.500 GR, UNPREP...
# 45376125  BF  CADBURY CHOCOLATE BAR FUDGE 127.500 GR, UNPREP...
# 45376125  BF  CADBURY CHOCOLATE BAR FUDGE 127.500 GR, UNPREP...
# 45376125  BF  CADBURY CHOCOLATE BAR FUDGE 127.500 GR, UNPREP...
#
#                               Manufacturer DataPoint  \
# Ndb Id
# 45318621  Mars Chocolate North America LLC        --
# 45318621  Mars Chocolate North America LLC        --
# 45318621  Mars Chocolate North America LLC        --
# 45318621  Mars Chocolate North America LLC        --
# 45318621  Mars Chocolate North America LLC        --
# 45318454  Mars Chocolate North America LLC        --
# 45318454  Mars Chocolate North America LLC        --
# 45318454  Mars Chocolate North America LLC        --
# 45318454  Mars Chocolate North America LLC        --
# 45318454  Mars Chocolate North America LLC        --
# 45236273                WEIS MARKETS, INC.        --
# 45236273                WEIS MARKETS, INC.        --
# 45236273                WEIS MARKETS, INC.        --
# 45236273                WEIS MARKETS, INC.        --
# 45236273                WEIS MARKETS, INC.      None
# 45331173     Lindt & Sprungli (Schweiz) AG        --
# 45331173     Lindt & Sprungli (Schweiz) AG        --
# 45331173     Lindt & Sprungli (Schweiz) AG        --
# 45331173     Lindt & Sprungli (Schweiz) AG        --
# 45331173     Lindt & Sprungli (Schweiz) AG        --
# 45158103        Bruno's Supermarkets, Inc.        --
# 45158103        Bruno's Supermarkets, Inc.        --
# 45158103        Bruno's Supermarkets, Inc.        --
# 45158103        Bruno's Supermarkets, Inc.        --
# 45158103        Bruno's Supermarkets, Inc.        --
# 45158934     GHIRARDELLI CHOCOLATE COMPANY        --
# 45158934     GHIRARDELLI CHOCOLATE COMPANY        --
# 45158934     GHIRARDELLI CHOCOLATE COMPANY        --
# 45158934     GHIRARDELLI CHOCOLATE COMPANY        --
# 45158934     GHIRARDELLI CHOCOLATE COMPANY        --
# ...                                    ...       ...
# 45375537                 Mondelez EU B2B2C        --
# 45375537                 Mondelez EU B2B2C        --
# 45375537                 Mondelez EU B2B2C      None
# 45375537                 Mondelez EU B2B2C      None
# 45375537                 Mondelez EU B2B2C      None
# 45375781                 Mondelez EU B2B2C        --
# 45375781                 Mondelez EU B2B2C        --
# 45375781                 Mondelez EU B2B2C      None
# 45375781                 Mondelez EU B2B2C      None
# 45375781                 Mondelez EU B2B2C      None
# 45375900                 Mondelez EU B2B2C        --
# 45375900                 Mondelez EU B2B2C        --
# 45375900                 Mondelez EU B2B2C      None
# 45375900                 Mondelez EU B2B2C      None
# 45375900                 Mondelez EU B2B2C      None
# 45369935  Mondelez Int. US (0074819091009)        --
# 45369935  Mondelez Int. US (0074819091009)        --
# 45369935  Mondelez Int. US (0074819091009)        --
# 45369935  Mondelez Int. US (0074819091009)        --
# 45369935  Mondelez Int. US (0074819091009)        --
# 45375862                 Mondelez EU B2B2C        --
# 45375862                 Mondelez EU B2B2C        --
# 45375862                 Mondelez EU B2B2C      None
# 45375862                 Mondelez EU B2B2C      None
# 45375862                 Mondelez EU B2B2C      None
# 45376125                 Mondelez EU B2B2C        --
# 45376125                 Mondelez EU B2B2C        --
# 45376125                 Mondelez EU B2B2C      None
# 45376125                 Mondelez EU B2B2C      None
# 45376125                 Mondelez EU B2B2C      None
#
#                                                    Nutrient StdError  Unit  \
# Ndb Id
# 45318621                                             Energy       --  kcal
# 45318621                        Carbohydrate, by difference       --     g
# 45318621                                           Iron, Fe       --    mg
# 45318621                                         Sodium, Na       --    mg
# 45318621                                      Vitamin A, IU       --    IU
# 45318454                                             Energy       --  kcal
# 45318454                        Carbohydrate, by difference       --     g
# 45318454                                           Iron, Fe       --    mg
# 45318454                                         Sodium, Na       --    mg
# 45318454                                      Vitamin A, IU       --    IU
# 45236273                                             Energy       --  kcal
# 45236273                        Carbohydrate, by difference       --     g
# 45236273                                           Iron, Fe       --    mg
# 45236273                                      Phosphorus, P       --    mg
# 45236273                                           Vitamins     None  None
# 45331173                                             Energy       --  kcal
# 45331173                        Carbohydrate, by difference       --     g
# 45331173                                           Iron, Fe       --    mg
# 45331173                                         Sodium, Na       --    mg
# 45331173                     Vitamin C, total ascorbic acid       --    mg
# 45158103                                             Energy       --  kcal
# 45158103                        Carbohydrate, by difference       --     g
# 45158103                                           Iron, Fe       --    mg
# 45158103                                         Sodium, Na       --    mg
# 45158103                     Vitamin C, total ascorbic acid       --    mg
# 45158934                                             Energy       --  kcal
# 45158934                        Carbohydrate, by difference       --     g
# 45158934                                           Iron, Fe       --    mg
# 45158934                                         Sodium, Na       --    mg
# 45158934                     Vitamin C, total ascorbic acid       --    mg
# ...                                                     ...      ...   ...
# 45375537                                            Protein       --     g
# 45375537                                      Sugars, total       --     g
# 45375537                                        Amino Acids     None  None
# 45375537                                              Other     None  None
# 45375537  Ingredients: MILK**, sugar, roasted HAZELNUTS,...     None  None
# 45375781                                            Protein       --     g
# 45375781                                      Sugars, total       --     g
# 45375781                                        Amino Acids     None  None
# 45375781                                              Other     None  None
# 45375781  Ingredients: MILK, sugar, cocoa butter, cocoa ...     None  None
# 45375900                                            Protein       --     g
# 45375900                                      Sugars, total       --     g
# 45375900                                        Amino Acids     None  None
# 45375900                                              Other     None  None
# 45375900  Ingredients: MILK**, sugar, cocoa butter, coco...     None  None
# 45369935                                            Protein       --     g
# 45369935                               Fiber, total dietary       --     g
# 45369935                                       Potassium, K       --    mg
# 45369935                                         Sodium, Na       --    mg
# 45369935                     Vitamin C, total ascorbic acid       --    mg
# 45375862                                            Protein       --     g
# 45375862                                      Sugars, total       --     g
# 45375862                                        Amino Acids     None  None
# 45375862                                              Other     None  None
# 45375862  Ingredients: Sugar, MILK, cocoa butter, cocoa ...     None  None
# 45376125                                            Protein       --     g
# 45376125                                      Sugars, total       --     g
# 45376125                                        Amino Acids     None  None
# 45376125                                              Other     None  None
# 45376125  Ingredients: Sugar, glucose syrup, palm oil, s...     None  None
#
#           Value Weight
# Ndb Id
# 45318621    476    200
# 45318621  73.81  31.00
# 45318621   0.86   0.36
# 45318621     71     30
# 45318621    238    100
# 45318454    524    220
# 45318454  57.14  24.00
# 45318454   0.86   0.36
# 45318454    214     90
# 45318454    238    100
# 45236273     62    149
# 45236273  10.00  24.00
# 45236273   0.15   0.36
# 45236273     83    199
# 45236273   None   None
# 45331173    611    220
# 45331173  44.44  16.00
# 45331173   1.00   0.36
# 45331173    125     45
# 45331173    0.0    0.0
# 45158103    500    200
# 45158103  72.50  29.00
# 45158103   0.90   0.36
# 45158103      0      0
# 45158103    0.0    0.0
# 45158934    523    230
# 45158934  56.82  25.00
# 45158934   3.27   1.44
# 45158934    148     65
# 45158934    0.0    0.0
# ...         ...    ...
# 45375537   8.80   8.80
# 45375537  48.00  48.00
# 45375537   None   None
# 45375537   None   None
# 45375537   None   None
# 45375781   7.70   7.70
# 45375781  56.00  56.00
# 45375781   None   None
# 45375781   None   None
# 45375781   None   None
# 45375900   7.50   7.50
# 45375900  56.00  56.00
# 45375900   None   None
# 45375900   None   None
# 45375900   None   None
# 45369935   7.69   1.00
# 45369935    0.0    0.0
# 45369935    308     40
# 45369935    538     70
# 45369935    0.0    0.0
# 45375862   4.20   4.20
# 45375862  69.00  69.00
# 45375862   None   None
# 45375862   None   None
# 45375862   None   None
# 45376125   2.40   2.40
# 45376125  65.00  65.00
# 45376125   None   None
# 45376125   None   None
# 45376125   None   None
#
# [100 rows x 9 columns]

# %% [markdown]
# # Part III - Munging using Twitter API

# %%
"""
Query creator for Twitter API. Creates a query column in the bfdb dataset.
    
@Author: Dhawal Priyadarshi
@Created On: Jan 2019
"""

bfdb['Query'] = bfdb.apply(lambda row: row['FoodDescription'].split(",")[0], axis=1)
bfdb
# Out:
#           Db                                    FoodDescription  \
# Ndb Id
# 45318621  BF               CHOCOLATE CANDIES, UPC: 040000249085
# 45318621  BF               CHOCOLATE CANDIES, UPC: 040000249085
# 45318621  BF               CHOCOLATE CANDIES, UPC: 040000249085
# 45318621  BF               CHOCOLATE CANDIES, UPC: 040000249085
# 45318621  BF               CHOCOLATE CANDIES, UPC: 040000249085
# 45318454  BF               CHOCOLATE CANDIES, UPC: 040000483632
# 45318454  BF               CHOCOLATE CANDIES, UPC: 040000483632
# 45318454  BF               CHOCOLATE CANDIES, UPC: 040000483632
# 45318454  BF               CHOCOLATE CANDIES, UPC: 040000483632
# 45318454  BF               CHOCOLATE CANDIES, UPC: 040000483632
# 45236273  BF  WEIS QUALITY, 1% LOW FAT CHOCOLATE MILK, CHOCO...
# 45236273  BF  WEIS QUALITY, 1% LOW FAT CHOCOLATE MILK, CHOCO...
# 45236273  BF  WEIS QUALITY, 1% LOW FAT CHOCOLATE MILK, CHOCO...
# 45236273  BF  WEIS QUALITY, 1% LOW FAT CHOCOLATE MILK, CHOCO...
# 45236273  BF  WEIS QUALITY, 1% LOW FAT CHOCOLATE MILK, CHOCO...
# 45331173  BF         MILK CHOCOLATE TRUFFLES, UPC: 009542034610
# 45331173  BF         MILK CHOCOLATE TRUFFLES, UPC: 009542034610
# 45331173  BF         MILK CHOCOLATE TRUFFLES, UPC: 009542034610
# 45331173  BF         MILK CHOCOLATE TRUFFLES, UPC: 009542034610
# 45331173  BF         MILK CHOCOLATE TRUFFLES, UPC: 009542034610
# 45158103  BF  SOUTHERN HOME, CHOCOLATE STARS, UPC: 607880038897
# 45158103  BF  SOUTHERN HOME, CHOCOLATE STARS, UPC: 607880038897
# 45158103  BF  SOUTHERN HOME, CHOCOLATE STARS, UPC: 607880038897
# 45158103  BF  SOUTHERN HOME, CHOCOLATE STARS, UPC: 607880038897
# 45158103  BF  SOUTHERN HOME, CHOCOLATE STARS, UPC: 607880038897
# 45158934  BF  GHIRARDELLI CHOCOLATE, MINIS ASSORTMENT, UPC: ...
# 45158934  BF  GHIRARDELLI CHOCOLATE, MINIS ASSORTMENT, UPC: ...
# 45158934  BF  GHIRARDELLI CHOCOLATE, MINIS ASSORTMENT, UPC: ...
# 45158934  BF  GHIRARDELLI CHOCOLATE, MINIS ASSORTMENT, UPC: ...
# 45158934  BF  GHIRARDELLI CHOCOLATE, MINIS ASSORTMENT, UPC: ...
# ...       ..                                                ...
# 45375537  BF  CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT, UNP...
# 45375537  BF  CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT, UNP...
# 45375537  BF  CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT, UNP...
# 45375537  BF  CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT, UNP...
# 45375537  BF  CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT, UNP...
# 45375781  BF  CADBURY FLAKE CHOCOLATE BAR, UNPREPARED, GTIN:...
# 45375781  BF  CADBURY FLAKE CHOCOLATE BAR, UNPREPARED, GTIN:...
# 45375781  BF  CADBURY FLAKE CHOCOLATE BAR, UNPREPARED, GTIN:...
# 45375781  BF  CADBURY FLAKE CHOCOLATE BAR, UNPREPARED, GTIN:...
# 45375781  BF  CADBURY FLAKE CHOCOLATE BAR, UNPREPARED, GTIN:...
# 45375900  BF  CADBURY FREDDO CHOCOLATE BAR, UNPREPARED, GTIN...
# 45375900  BF  CADBURY FREDDO CHOCOLATE BAR, UNPREPARED, GTIN...
# 45375900  BF  CADBURY FREDDO CHOCOLATE BAR, UNPREPARED, GTIN...
# 45375900  BF  CADBURY FREDDO CHOCOLATE BAR, UNPREPARED, GTIN...
# 45375900  BF  CADBURY FREDDO CHOCOLATE BAR, UNPREPARED, GTIN...
# 45369935  BF  NABISCO OREO CONES CHOCOLATE 1X4.750 OZ, UNPRE...
# 45369935  BF  NABISCO OREO CONES CHOCOLATE 1X4.750 OZ, UNPRE...
# 45369935  BF  NABISCO OREO CONES CHOCOLATE 1X4.750 OZ, UNPRE...
# 45369935  BF  NABISCO OREO CONES CHOCOLATE 1X4.750 OZ, UNPRE...
# 45369935  BF  NABISCO OREO CONES CHOCOLATE 1X4.750 OZ, UNPRE...
# 45375862  BF  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR, ...
# 45375862  BF  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR, ...
# 45375862  BF  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR, ...
# 45375862  BF  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR, ...
# 45375862  BF  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR, ...
# 45376125  BF  CADBURY CHOCOLATE BAR FUDGE 127.500 GR, UNPREP...
# 45376125  BF  CADBURY CHOCOLATE BAR FUDGE 127.500 GR, UNPREP...
# 45376125  BF  CADBURY CHOCOLATE BAR FUDGE 127.500 GR, UNPREP...
# 45376125  BF  CADBURY CHOCOLATE BAR FUDGE 127.500 GR, UNPREP...
# 45376125  BF  CADBURY CHOCOLATE BAR FUDGE 127.500 GR, UNPREP...
#
#                               Manufacturer DataPoint  \
# Ndb Id
# 45318621  Mars Chocolate North America LLC        --
# 45318621  Mars Chocolate North America LLC        --
# 45318621  Mars Chocolate North America LLC        --
# 45318621  Mars Chocolate North America LLC        --
# 45318621  Mars Chocolate North America LLC        --
# 45318454  Mars Chocolate North America LLC        --
# 45318454  Mars Chocolate North America LLC        --
# 45318454  Mars Chocolate North America LLC        --
# 45318454  Mars Chocolate North America LLC        --
# 45318454  Mars Chocolate North America LLC        --
# 45236273                WEIS MARKETS, INC.        --
# 45236273                WEIS MARKETS, INC.        --
# 45236273                WEIS MARKETS, INC.        --
# 45236273                WEIS MARKETS, INC.        --
# 45236273                WEIS MARKETS, INC.      None
# 45331173     Lindt & Sprungli (Schweiz) AG        --
# 45331173     Lindt & Sprungli (Schweiz) AG        --
# 45331173     Lindt & Sprungli (Schweiz) AG        --
# 45331173     Lindt & Sprungli (Schweiz) AG        --
# 45331173     Lindt & Sprungli (Schweiz) AG        --
# 45158103        Bruno's Supermarkets, Inc.        --
# 45158103        Bruno's Supermarkets, Inc.        --
# 45158103        Bruno's Supermarkets, Inc.        --
# 45158103        Bruno's Supermarkets, Inc.        --
# 45158103        Bruno's Supermarkets, Inc.        --
# 45158934     GHIRARDELLI CHOCOLATE COMPANY        --
# 45158934     GHIRARDELLI CHOCOLATE COMPANY        --
# 45158934     GHIRARDELLI CHOCOLATE COMPANY        --
# 45158934     GHIRARDELLI CHOCOLATE COMPANY        --
# 45158934     GHIRARDELLI CHOCOLATE COMPANY        --
# ...                                    ...       ...
# 45375537                 Mondelez EU B2B2C        --
# 45375537                 Mondelez EU B2B2C        --
# 45375537                 Mondelez EU B2B2C      None
# 45375537                 Mondelez EU B2B2C      None
# 45375537                 Mondelez EU B2B2C      None
# 45375781                 Mondelez EU B2B2C        --
# 45375781                 Mondelez EU B2B2C        --
# 45375781                 Mondelez EU B2B2C      None
# 45375781                 Mondelez EU B2B2C      None
# 45375781                 Mondelez EU B2B2C      None
# 45375900                 Mondelez EU B2B2C        --
# 45375900                 Mondelez EU B2B2C        --
# 45375900                 Mondelez EU B2B2C      None
# 45375900                 Mondelez EU B2B2C      None
# 45375900                 Mondelez EU B2B2C      None
# 45369935  Mondelez Int. US (0074819091009)        --
# 45369935  Mondelez Int. US (0074819091009)        --
# 45369935  Mondelez Int. US (0074819091009)        --
# 45369935  Mondelez Int. US (0074819091009)        --
# 45369935  Mondelez Int. US (0074819091009)        --
# 45375862                 Mondelez EU B2B2C        --
# 45375862                 Mondelez EU B2B2C        --
# 45375862                 Mondelez EU B2B2C      None
# 45375862                 Mondelez EU B2B2C      None
# 45375862                 Mondelez EU B2B2C      None
# 45376125                 Mondelez EU B2B2C        --
# 45376125                 Mondelez EU B2B2C        --
# 45376125                 Mondelez EU B2B2C      None
# 45376125                 Mondelez EU B2B2C      None
# 45376125                 Mondelez EU B2B2C      None
#
#                                                    Nutrient StdError  Unit  \
# Ndb Id
# 45318621                                             Energy       --  kcal
# 45318621                        Carbohydrate, by difference       --     g
# 45318621                                           Iron, Fe       --    mg
# 45318621                                         Sodium, Na       --    mg
# 45318621                                      Vitamin A, IU       --    IU
# 45318454                                             Energy       --  kcal
# 45318454                        Carbohydrate, by difference       --     g
# 45318454                                           Iron, Fe       --    mg
# 45318454                                         Sodium, Na       --    mg
# 45318454                                      Vitamin A, IU       --    IU
# 45236273                                             Energy       --  kcal
# 45236273                        Carbohydrate, by difference       --     g
# 45236273                                           Iron, Fe       --    mg
# 45236273                                      Phosphorus, P       --    mg
# 45236273                                           Vitamins     None  None
# 45331173                                             Energy       --  kcal
# 45331173                        Carbohydrate, by difference       --     g
# 45331173                                           Iron, Fe       --    mg
# 45331173                                         Sodium, Na       --    mg
# 45331173                     Vitamin C, total ascorbic acid       --    mg
# 45158103                                             Energy       --  kcal
# 45158103                        Carbohydrate, by difference       --     g
# 45158103                                           Iron, Fe       --    mg
# 45158103                                         Sodium, Na       --    mg
# 45158103                     Vitamin C, total ascorbic acid       --    mg
# 45158934                                             Energy       --  kcal
# 45158934                        Carbohydrate, by difference       --     g
# 45158934                                           Iron, Fe       --    mg
# 45158934                                         Sodium, Na       --    mg
# 45158934                     Vitamin C, total ascorbic acid       --    mg
# ...                                                     ...      ...   ...
# 45375537                                            Protein       --     g
# 45375537                                      Sugars, total       --     g
# 45375537                                        Amino Acids     None  None
# 45375537                                              Other     None  None
# 45375537  Ingredients: MILK**, sugar, roasted HAZELNUTS,...     None  None
# 45375781                                            Protein       --     g
# 45375781                                      Sugars, total       --     g
# 45375781                                        Amino Acids     None  None
# 45375781                                              Other     None  None
# 45375781  Ingredients: MILK, sugar, cocoa butter, cocoa ...     None  None
# 45375900                                            Protein       --     g
# 45375900                                      Sugars, total       --     g
# 45375900                                        Amino Acids     None  None
# 45375900                                              Other     None  None
# 45375900  Ingredients: MILK**, sugar, cocoa butter, coco...     None  None
# 45369935                                            Protein       --     g
# 45369935                               Fiber, total dietary       --     g
# 45369935                                       Potassium, K       --    mg
# 45369935                                         Sodium, Na       --    mg
# 45369935                     Vitamin C, total ascorbic acid       --    mg
# 45375862                                            Protein       --     g
# 45375862                                      Sugars, total       --     g
# 45375862                                        Amino Acids     None  None
# 45375862                                              Other     None  None
# 45375862  Ingredients: Sugar, MILK, cocoa butter, cocoa ...     None  None
# 45376125                                            Protein       --     g
# 45376125                                      Sugars, total       --     g
# 45376125                                        Amino Acids     None  None
# 45376125                                              Other     None  None
# 45376125  Ingredients: Sugar, glucose syrup, palm oil, s...     None  None
#
#           Value Weight                                         Query
# Ndb Id
# 45318621    476    200                             CHOCOLATE CANDIES
# 45318621  73.81  31.00                             CHOCOLATE CANDIES
# 45318621   0.86   0.36                             CHOCOLATE CANDIES
# 45318621     71     30                             CHOCOLATE CANDIES
# 45318621    238    100                             CHOCOLATE CANDIES
# 45318454    524    220                             CHOCOLATE CANDIES
# 45318454  57.14  24.00                             CHOCOLATE CANDIES
# 45318454   0.86   0.36                             CHOCOLATE CANDIES
# 45318454    214     90                             CHOCOLATE CANDIES
# 45318454    238    100                             CHOCOLATE CANDIES
# 45236273     62    149                                  WEIS QUALITY
# 45236273  10.00  24.00                                  WEIS QUALITY
# 45236273   0.15   0.36                                  WEIS QUALITY
# 45236273     83    199                                  WEIS QUALITY
# 45236273   None   None                                  WEIS QUALITY
# 45331173    611    220                       MILK CHOCOLATE TRUFFLES
# 45331173  44.44  16.00                       MILK CHOCOLATE TRUFFLES
# 45331173   1.00   0.36                       MILK CHOCOLATE TRUFFLES
# 45331173    125     45                       MILK CHOCOLATE TRUFFLES
# 45331173    0.0    0.0                       MILK CHOCOLATE TRUFFLES
# 45158103    500    200                                 SOUTHERN HOME
# 45158103  72.50  29.00                                 SOUTHERN HOME
# 45158103   0.90   0.36                                 SOUTHERN HOME
# 45158103      0      0                                 SOUTHERN HOME
# 45158103    0.0    0.0                                 SOUTHERN HOME
# 45158934    523    230                         GHIRARDELLI CHOCOLATE
# 45158934  56.82  25.00                         GHIRARDELLI CHOCOLATE
# 45158934   3.27   1.44                         GHIRARDELLI CHOCOLATE
# 45158934    148     65                         GHIRARDELLI CHOCOLATE
# 45158934    0.0    0.0                         GHIRARDELLI CHOCOLATE
# ...         ...    ...                                           ...
# 45375537   8.80   8.80     CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT
# 45375537  48.00  48.00     CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT
# 45375537   None   None     CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT
# 45375537   None   None     CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT
# 45375537   None   None     CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT
# 45375781   7.70   7.70                   CADBURY FLAKE CHOCOLATE BAR
# 45375781  56.00  56.00                   CADBURY FLAKE CHOCOLATE BAR
# 45375781   None   None                   CADBURY FLAKE CHOCOLATE BAR
# 45375781   None   None                   CADBURY FLAKE CHOCOLATE BAR
# 45375781   None   None                   CADBURY FLAKE CHOCOLATE BAR
# 45375900   7.50   7.50                  CADBURY FREDDO CHOCOLATE BAR
# 45375900  56.00  56.00                  CADBURY FREDDO CHOCOLATE BAR
# 45375900   None   None                  CADBURY FREDDO CHOCOLATE BAR
# 45375900   None   None                  CADBURY FREDDO CHOCOLATE BAR
# 45375900   None   None                  CADBURY FREDDO CHOCOLATE BAR
# 45369935   7.69   1.00       NABISCO OREO CONES CHOCOLATE 1X4.750 OZ
# 45369935    0.0    0.0       NABISCO OREO CONES CHOCOLATE 1X4.750 OZ
# 45369935    308     40       NABISCO OREO CONES CHOCOLATE 1X4.750 OZ
# 45369935    538     70       NABISCO OREO CONES CHOCOLATE 1X4.750 OZ
# 45369935    0.0    0.0       NABISCO OREO CONES CHOCOLATE 1X4.750 OZ
# 45375862   4.20   4.20  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR
# 45375862  69.00  69.00  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR
# 45375862   None   None  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR
# 45375862   None   None  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR
# 45375862   None   None  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR
# 45376125   2.40   2.40        CADBURY CHOCOLATE BAR FUDGE 127.500 GR
# 45376125  65.00  65.00        CADBURY CHOCOLATE BAR FUDGE 127.500 GR
# 45376125   None   None        CADBURY CHOCOLATE BAR FUDGE 127.500 GR
# 45376125   None   None        CADBURY CHOCOLATE BAR FUDGE 127.500 GR
# 45376125   None   None        CADBURY CHOCOLATE BAR FUDGE 127.500 GR
#
# [100 rows x 10 columns]

# %%
"""
Twitter querying classes.
    
@Author: Dhawal Priyadarshi
@Created On: Jan 2019
@Credits: VP Russo: https://github.com/vprusso/youtube_tutorials/tree/master/twitter_python
"""
# # # # TWITTER AUTHENTICATOR CLASS# # # #
class TwitterAuthenticator():

    def authenticate_twitter_app(self):
        """
        Twitter API authenticator function
        
        @Author: VP Russo: https://github.com/vprusso/youtube_tutorials/tree/master/twitter_python
        """
        auth = OAuthHandler(twitter_credentials.CONSUMER_KEY, twitter_credentials.CONSUMER_SECRET)
        auth.set_access_token(twitter_credentials.ACCESS_TOKEN, twitter_credentials.ACCESS_TOKEN_SECRET)
        return auth

# # # # TWEET QUERYING CLASS # # # #
class TweetQuery():
    """
    This class runs search queries using Tweepy API
    """
    def __init__(self):
        self.twitter_authenticator = TwitterAuthenticator()

    """
    Takes filename, query string, and optional count of number of tweets.
    Appends the tweets to a given file name
    
    @Author: Dhawal Priyadarshi
    @Credits: VPRusso: https://github.com/vprusso/youtube_tutorials/tree/master/twitter_python
    @Credits: VickyQian: https://gist.github.com/vickyqian/f70e9ab3910c7c290d9d715491cde44c
    """
    def search(self, ndbid, query, count = 15):
        auth = self.twitter_authenticator.authenticate_twitter_app()
        api = API(auth)
        tweet_df = pd.DataFrame(columns=['Ndb Id','Tweet_Created','Tweet_Text'])
        try:
            for tweet in Cursor(api.search, q = query, count = count, tweet_mode = 'extended', lang = 'en').items():
                temp_dict = {
                    'Ndb Id': ndbid,
                    'Tweet_Created': tweet.created_at,
                    'Tweet_Text': tweet.full_text
                }
                tweet_df = tweet_df.append(temp_dict, ignore_index=True)
            return tweet_df

        except TweepError as e:
            print(e.response.text, "Going to sleep for 15 mins")
            time.sleep(60 * 15)
        return None
    
print("Classes defined!")
# Out:
# Classes defined!

# %%
# Creating data frame for queries

queries = pd.DataFrame(bfdb['Query'])
queries = queries.drop_duplicates()
queries
# Out:
#                                                  Query
# Ndb Id
# 45318621                             CHOCOLATE CANDIES
# 45236273                                  WEIS QUALITY
# 45331173                       MILK CHOCOLATE TRUFFLES
# 45158103                                 SOUTHERN HOME
# 45158934                         GHIRARDELLI CHOCOLATE
# 45148117                                         KINGS
# 45004850                                          WEIS
# 45053347                    DARK CHOCOLATE NON PAREILS
# 45208905                    PREMIUM MILK CHOCOLATE BAR
# 45145291                                  WILD HARVEST
# 45153224                                    MARKETSIDE
# 45318334       MILK CHOCOLATE & STRAWBERRY CREME SWIRL
# 45143068       CHOCOLATE RAISINS WITH SEA SALT CARAMEL
# 45375537     CADBURY DAIRY MILK CHOCOLATE BAR WHOLENUT
# 45375781                   CADBURY FLAKE CHOCOLATE BAR
# 45375900                  CADBURY FREDDO CHOCOLATE BAR
# 45369935       NABISCO OREO CONES CHOCOLATE 1X4.750 OZ
# 45375862  CADBURY MINI EGGS CHOCOLATE EGGS MINI 328 GR
# 45376125        CADBURY CHOCOLATE BAR FUDGE 127.500 GR

# %%
# Hitting the Twitter API with the query strings in the Query dataframe

tweets_all = pd.DataFrame(columns=['Ndb Id','Tweet_Created','Tweet_Text'])
max_query_count = 100       # putting a hard limit to number of requests to avoid API rate_limit error
t_query = TweetQuery()
for idx, val in enumerate(queries.index.values):
    print("Iteration:", idx, val)
    if i <= max_query_count:
        query = queries.loc[val,'Query']     # val is the index/NDB ID
        ndbid = val
        tweets = t_query.search(ndbid, query, count = 10)
        tweets_all = tweets_all.append(tweets, ignore_index=True)
tweets_all
# Out:
# Iteration: 0 45318621
# Iteration: 1 45236273
# Iteration: 2 45331173
# Iteration: 3 45158103
# Iteration: 4 45158934
# {"errors":[{"message":"Rate limit exceeded","code":88}]} Going to sleep for 15 mins
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-90-ad2a7ad8514e> in search(self, ndbid, query, count)
#      27         try:
# ---> 28             for tweet in Cursor(api.search, q = query, count = count, tweet_mode = 'extended', lang = 'en').items():
#      29                 temp_dict = {
#
# ~/proj/Scraping/venv/lib/python3.7/site-packages/tweepy/cursor.py in __next__(self)
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#
# ~/proj/Scraping/venv/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#
# ~/proj/Scraping/venv/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#
# ~/proj/Scraping/venv/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     249         else:
# --> 250             return method.execute()
#     251
#
# ~/proj/Scraping/venv/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     233                 else:
# --> 234                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     235
#
# TweepError: Twitter error response: status code = 429
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-95f510fcf4ef> in <module>
#       7         query = queries.loc[val,'Query']     # val is the index/NDB ID
#       8         ndbid = val
# ----> 9         tweets = t_query.search(ndbid, query, count = 10)
#      10         tweets_all = tweets_all.append(tweets, ignore_index=True)
#      11 tweets_all
#
# <ipython-input-90-ad2a7ad8514e> in search(self, ndbid, query, count)
#      37         except TweepError as e:
#      38             print(e.response.text, "Going to sleep for 15 mins")
# ---> 39             time.sleep(60 * 15)
#      40 #         except BaseException as e:
#      41 #             print("Base Exception: %s" % str(e))
#
# KeyboardInterrupt:

# %%
